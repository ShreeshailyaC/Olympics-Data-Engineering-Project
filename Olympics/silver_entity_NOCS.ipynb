# %% [markdown]
# ## Silver Notebook

# %%
df = spark.read.format("csv")\
    .option("header",True)\
    .option("inferschema",True)\
    .load("abfss://bronze@olympicsprojectstorage.dfs.core.windows.net/nocs")

# %%
display(df)

# %%
df = df.drop('country')

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df = df.withColumn('tag',split(col('tag'),'-')[0])
df.display()

# %%
df.write.format("delta")\
    .mode("append")\
    .option("path","abfss://silver@olympicsprojectstorage.dfs.core.windows.net/nocs")\
    .saveAsTable("olympicscatalog.silver.nocs")
